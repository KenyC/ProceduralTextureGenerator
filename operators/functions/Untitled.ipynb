# %%
b = True
for i in range(1):
    print("~~~~~~~~~~~~~~~{}~~~~~~~~~~~~~~~~~~~~~~".format(i))
    try:
        # %run voronoi.py
    except TypeError as e:
        b = False
        print("BHDT")
        print(e)
        break
if b:
    print("Did it without crashing")
# Out:
# ~~~~~~~~~~~~~~~0~~~~~~~~~~~~~~~~~~~~~~
# ########################################################
# INSERT 1 in 0 x= 11.059856444257194
# List at insert
# [parent: False, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# ########################################################
# (2,)
# (2,)
# INSERT 2 in 1 x= 27.020503434338938
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743)) and 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# Will occur at x= 359.5669264736516
# Checking 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275)) and 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 3 in 2 x= 44.020769008795575
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638)) and 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743))
# Will occur at x= 686.0147780396585
# Checking 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743)) and 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 4 in 1 x= 63.038713425703584
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# had to disable: 2 1 0
# #END DISABLING#
# Checking 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639)) and 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# Will occur at x= 77.75653083773311
# Checking 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743)) and 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (-25.10062141720772, -51.97885698144639))
# Will occur at x= 63.504133605046576
# ########################################################
# DELETE  2 1 4 x= 63.504133605046576
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (-25.10062141720772, -51.97885698144639))
# [parent: True, focus: 4, edge: None]
#
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 3 2 1
# END DISABLING
# Checking 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638)) and 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# Will occur at x= 119.13878649189702
# Checking 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464)) and 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 5 in 4 x= 73.97480329865382
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241)) and 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# Will occur at x= 93.48851596159213
# Checking 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464)) and 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# Will occur at x= 183.7530372444287
# ########################################################
# DELETE  4 1 0 x= 77.75653083773311
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 5 4 1
# END DISABLING
# Checking 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241)) and 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# Will occur at x= 93.01418107746446
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 6 in 3 x= 81.02813873496697
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714)) and 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# Will occur at x= 100.40942596510176
# Checking 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638)) and 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 7 in 3 x= 86.9932647201667
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# had to disable: 6 3 2
# #END DISABLING#
# Checking 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (-26.038251580500656, 42.97249571137113)) and 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# Will occur at x= 87.10831819391944
# Checking 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714)) and 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (26.038251580500656, -42.97249571137113))
# Will occur at x= 88.53693398767282
# ########################################################
# DELETE  7 3 2 x= 87.10831819391944
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (26.038251580500656, -42.97249571137113))
# [parent: True, focus: 7, edge: None]
#
# 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (-26.038251580500656, 42.97249571137113))
# [parent: True, focus: 3, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 3 2 1
# had to disable: 3 2 4
# END DISABLING
# Checking 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (26.038251580500656, -42.97249571137113)) and 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# I swear I didn't find anything
# Checking 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777)) and 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# Will occur at x= 94.2958699665771
# ########################################################
# DELETE  6 3 7 x= 88.53693398767282
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (26.038251580500656, -42.97249571137113))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714)) and 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# I swear I didn't find anything
# Checking 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734)) and 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# I swear I didn't find anything
# ########################################################
# DELETE  5 4 0 x= 93.01418107746446
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241)) and 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# I swear I didn't find anything
# ########################################################
# DELETE  7 2 4 x= 94.2958699665771
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 2 4 5
# END DISABLING
# Checking 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734)) and 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# I swear I didn't find anything
# Checking 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123)) and 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# Will occur at x= 111.85252593288183
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 8 in 3 x= 97.01672517655193
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354)) and 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# Will occur at x= 115.91759651154959
# Checking 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638)) and 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 9 in 5 x= 110.9216303512591
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (-44.99267729607661, 36.94682705260527)) and 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# Will occur at x= 111.31582190722486
# Checking 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241)) and 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# I swear I didn't find anything
# ########################################################
# DELETE  9 5 0 x= 111.31582190722486
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (-44.99267729607661, 36.94682705260527))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527)) and 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# I swear I didn't find anything
# ########################################################
# DELETE  7 4 5 x= 111.85252593288183
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734)) and 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# I swear I didn't find anything
# Checking 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882)) and 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# Will occur at x= 209.20011479906404
# ########################################################
# DELETE  8 3 6 x= 115.91759651154959
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354)) and 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957))
# I swear I didn't find anything
# Checking 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957)) and 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# Will occur at x= 393.8132062082873
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 10 in 8 x= 127.92470050380746
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (-41.06026745681656, 30.907975327255528)) and 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957))
# Will occur at x= 128.0571477433076
# Checking 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354)) and 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# I swear I didn't find anything
# ########################################################
# DELETE  10 8 6 x= 128.0571477433076
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (-41.06026745681656, 30.907975327255528))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 8 6 7
# END DISABLING
# Checking 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528)) and 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# I swear I didn't find anything
# Checking 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485)) and 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# Will occur at x= 188.44605796735337
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 11 in 7 x= 151.98377025940155
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (-35.07682479762465, 64.99050553923485)) and 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# Will occur at x= 152.00055106314053
# Checking 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734)) and 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# Will occur at x= 205.5940922541754
# ########################################################
# DELETE  11 7 5 x= 152.00055106314053
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# [parent: True, focus: 11, edge: None]
#
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (-35.07682479762465, 64.99050553923485))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 7 5 9
# END DISABLING
# Checking 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485)) and 11 -> 5 (orig = (109.37718002557676, 191.27970675757552), dir = (24.932464239253505, 78.00896696074773))
# I swear I didn't find anything
# Checking 11 -> 5 (orig = (109.37718002557676, 191.27970675757552), dir = (24.932464239253505, 78.00896696074773)) and 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# Will occur at x= 161.19010849577086
# ########################################################
# DELETE  11 5 9 x= 161.19010849577086
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# [parent: True, focus: 11, edge: None]
#
# 11 -> 5 (orig = (109.37718002557676, 191.27970675757552), dir = (24.932464239253505, 78.00896696074773))
# [parent: True, focus: 5, edge: None]
#
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485)) and 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456))
# I swear I didn't find anything
# Checking 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456)) and 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# I swear I didn't find anything
# ########################################################
# DELETE  10 6 7 x= 188.44605796735337
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# [parent: True, focus: 11, edge: None]
#
# 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 6 7 11
# END DISABLING
# Checking 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528)) and 10 -> 7 (orig = (134.71490927774994, 130.31524201101166), dir = (77.99208850440287, 40.93143578364075))
# I swear I didn't find anything
# Checking 10 -> 7 (orig = (134.71490927774994, 130.31524201101166), dir = (77.99208850440287, 40.93143578364075)) and 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# Will occur at x= 198.41499930107415
# ########################################################
# DELETE  10 7 11 x= 198.41499930107415
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 7 (orig = (134.71490927774994, 130.31524201101166), dir = (77.99208850440287, 40.93143578364075))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# [parent: True, focus: 11, edge: None]
#
# 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528)) and 10 -> 11 (orig = (140.61097407913374, 133.40958660957182), dir = (113.06891330202752, -24.059069755594095))
# I swear I didn't find anything
# Checking 10 -> 11 (orig = (140.61097407913374, 133.40958660957182), dir = (113.06891330202752, -24.059069755594095)) and 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 12 in 8 x= 205.00871298437605
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# ...
# [parent: True, focus: 16, edge: None]
#
# 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (-13.92636694309644, -23.95458006933484))
# [parent: True, focus: 19, edge: None]
#
# 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (13.92636694309644, 23.95458006933484))
# [parent: True, focus: 16, edge: None]
#
# 16 -> 17 (orig = (220.47985653361397, 206.17243583805075), dir = (114.99836579135564, -1.947506623600816))
# [parent: True, focus: 17, edge: None]
#
# 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# [parent: True, focus: 14, edge: None]
#
# 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (-26.022042958309157, 126.18399735391498))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 18 15 16
# END DISABLING
# Checking 18 -> 15 (orig = (253.77673804730324, 38.91525466148624), dir = (68.91557953988473, 26.10670407932389)) and 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055))
# Will occur at x= 402.93529391579295
# Checking 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055)) and 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (13.92636694309644, 23.95458006933484))
# I swear I didn't find anything
# ########################################################
# DELETE  19 16 17 x= 383.93691949961004
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 12 (orig = (150.55488551188185, 26.01052554930318), dir = (-9.944079359733326, -107.99198780782412))
# [parent: True, focus: 12, edge: None]
#
# 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (-19.96477985786345, -66.01406613236148))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 15 (orig = (253.77673804730324, 38.91525466148624), dir = (68.91557953988473, 26.10670407932389))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055))
# [parent: True, focus: 19, edge: None]
#
# 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (13.92636694309644, 23.95458006933484))
# [parent: True, focus: 16, edge: None]
#
# 16 -> 17 (orig = (220.47985653361397, 206.17243583805075), dir = (114.99836579135564, -1.947506623600816))
# [parent: True, focus: 17, edge: None]
#
# 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# [parent: True, focus: 14, edge: None]
#
# 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (-26.022042958309157, 126.18399735391498))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055)) and 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022))
# I swear I didn't find anything
# Checking 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022)) and 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# I swear I didn't find anything
# ########################################################
# DELETE  18 15 19 x= 402.93529391579295
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 12 (orig = (150.55488551188185, 26.01052554930318), dir = (-9.944079359733326, -107.99198780782412))
# [parent: True, focus: 12, edge: None]
#
# 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (-19.96477985786345, -66.01406613236148))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 15 (orig = (253.77673804730324, 38.91525466148624), dir = (68.91557953988473, 26.10670407932389))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022))
# [parent: True, focus: 17, edge: None]
#
# 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# [parent: True, focus: 14, edge: None]
#
# 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (-26.022042958309157, 126.18399735391498))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (-19.96477985786345, -66.01406613236148)) and 18 -> 19 (orig = (323.6351547948332, 65.37912575789551), dir = (128.01469835451056, -12.971631704016659))
# I swear I didn't find anything
# Checking 18 -> 19 (orig = (323.6351547948332, 65.37912575789551), dir = (128.01469835451056, -12.971631704016659)) and 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022))
# I swear I didn't find anything
# ########################################################
# DELETE  8 12 18 x= 551.2499325486215
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 12 (orig = (150.55488551188185, 26.01052554930318), dir = (-9.944079359733326, -107.99198780782412))
# [parent: True, focus: 12, edge: None]
#
# 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (-19.96477985786345, -66.01406613236148))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 19 (orig = (323.6351547948332, 65.37912575789551), dir = (128.01469835451056, -12.971631704016659))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022))
# [parent: True, focus: 17, edge: None]
#
# 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# [parent: True, focus: 14, edge: None]
#
# 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (-26.022042958309157, 126.18399735391498))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354)) and 8 -> 18 (orig = (110.9470363391641, -404.1278724078285), dir = (-29.908859217596778, -174.0060539401856))
# I swear I didn't find anything
# Checking 8 -> 18 (orig = (110.9470363391641, -404.1278724078285), dir = (-29.908859217596778, -174.0060539401856)) and 18 -> 19 (orig = (323.6351547948332, 65.37912575789551), dir = (128.01469835451056, -12.971631704016659))
# I swear I didn't find anything
# ############### BEFORE COMPILING #########################
# 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (3.0226581268296115, 0.09731431272131275))
# INCOMPLETE EDGE 0 -> 1 (orig = (-35.93185511076093, 235.06141580856902), dir = (-3.0226581268296115, -0.09731431272131275))
# 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (66.06431714336833, 15.960646990081743))
# INCOMPLETE EDGE 1 -> 2 (orig = (-117.68654556035531, 168.9970986652007), dir = (-66.06431714336833, -15.960646990081743))
# 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (40.028389375445414, 17.000265574456638))
# INCOMPLETE EDGE 2 -> 3 (orig = (-11.604273356308063, 128.96870928975528), dir = (-40.028389375445414, -17.000265574456638))
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (25.10062141720772, 51.97885698144639))
# 1 -> 4 (orig = (30.988732316875716, 209.9607943913613), dir = (-25.10062141720772, -51.97885698144639))
# 2 -> 4 (orig = (28.230815470852093, 204.24964633158032), dir = (40.96369572616061, -36.01820999136464))
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (-5.055455515772792, 10.936089872950241))
# 4 -> 5 (orig = (67.33825889075551, 215.0162499071341), dir = (5.055455515772792, -10.936089872950241))
# 4 -> 0 (orig = (44.358102184641716, 237.64634658299997), dir = (28.12327954403733, 52.0761712941677))
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (0.8368152104403919, 37.0073697261714))
# 3 -> 6 (orig = (62.514992787486385, 128.1318940793149), dir = (-0.8368152104403919, -37.0073697261714))
# 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (-26.038251580500656, 42.97249571137113))
# 3 -> 7 (orig = (57.61836001379189, 155.00696087025594), dir = (26.038251580500656, -42.97249571137113))
# 7 -> 2 (orig = (55.99867060848387, 157.6800319022401), dir = (13.990137794944758, 59.97276128582777))
# 6 -> 7 (orig = (62.9246733185266, 146.24963225216754), dir = (26.875066790941048, -5.965125985199734))
# 5 -> 0 (orig = (51.10320675278761, 250.1363273598796), dir = (23.06782402826454, 63.01226116711794))
# 7 -> 4 (orig = (60.28707049254804, 176.06349504711955), dir = (54.953833521105366, 23.954551294463123))
# 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (93.01410438071878, 52.995956167756354))
# INCOMPLETE EDGE 3 -> 8 (orig = (-11.106571510512836, 35.954604909036505), dir = (-93.01410438071878, -52.995956167756354))
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (-44.99267729607661, 36.94682705260527))
# 5 -> 9 (orig = (65.05288721537173, 260.0089272032107), dir = (44.99267729607661, -36.94682705260527))
# INCOMPLETE EDGE 9 -> 0 (orig = (57.106309207841505, 266.53445226526026), dir = (-21.92485326781207, 99.95908821972321))
# 7 -> 5 (orig = (81.14254669867545, 185.15446363911533), dir = (60.00928903687816, 13.018461421512882))
# 8 -> 6 (orig = (61.36435070551194, 77.24582458768853), dir = (92.17728917027839, 15.988586441584957))
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (-41.06026745681656, 30.907975327255528))
# 8 -> 10 (orig = (85.19707964721873, 77.01487236585307), dir = (41.06026745681656, -30.907975327255528))
# 10 -> 6 (orig = (80.48444133737607, 80.56229467039812), dir = (51.117021713461824, 46.896561768840485))
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (-35.07682479762465, 64.99050553923485))
# 7 -> 11 (orig = (110.02264530064974, 190.0837856678806), dir = (35.07682479762465, -64.99050553923485))
# 11 -> 5 (orig = (109.37718002557676, 191.27970675757552), dir = (24.932464239253505, 78.00896696074773))
# 11 -> 9 (orig = (117.5623382228594, 216.88951929969235), dir = (69.92514153533011, 41.062139908142456))
# 10 -> 7 (orig = (134.71490927774994, 130.31524201101166), dir = (77.99208850440287, 40.93143578364075))
# 10 -> 11 (orig = (140.61097407913374, 133.40958660957182), dir = (113.06891330202752, -24.059069755594095))
# 8 -> 12 (orig = (150.55488551188185, 26.01052554930318), dir = (9.944079359733326, 107.99198780782412))
# 8 -> 12 (orig = (150.55488551188185, 26.01052554930318), dir = (-9.944079359733326, -107.99198780782412))
# 12 -> 10 (orig = (150.71044682120325, 27.699910198387034), dir = (51.004346816549884, 77.08401248056859))
# 12 -> 13 (orig = (184.30165503778466, 68.9669266557392), dir = (-42.95640110643602, 26.979781378535932))
# 12 -> 13 (orig = (184.30165503778466, 68.9669266557392), dir = (42.95640110643602, -26.979781378535932))
# 13 -> 10 (orig = (179.8610889434549, 71.75592897753766), dir = (8.047945710113865, 104.06379385910452))
# INCOMPLETE EDGE 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (-26.022042958309157, 126.18399735391498))
# 9 -> 14 (orig = (171.33045709705303, 286.03097016151986), dir = (26.022042958309157, -126.18399735391498))
# 13 -> 15 (orig = (237.06251134706153, 74.96132523132447), dir = (-5.994398575585265, 12.927580674501655))
# 13 -> 15 (orig = (237.06251134706153, 74.96132523132447), dir = (5.994398575585265, -12.927580674501655))
# 11 -> 14 (orig = (178.24082937331366, 252.52174882869582), dir = (95.94718449363927, -85.12185744577252))
# 13 -> 11 (orig = (183.91654548828797, 124.19492509995227), dir = (121.11685901214139, 80.00472410351043))
# 11 -> 16 (orig = (197.81163445715217, 147.98681098904672), dir = (42.096974678833874, 108.05606049201779))
# 11 -> 16 (orig = (197.81163445715217, 147.98681098904672), dir = (-42.096974678833874, -108.05606049201779))
# INCOMPLETE EDGE 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (23.045793381117505, 24.88170966984609))
# 14 -> 17 (orig = (238.873811738685, 262.98517678040236), dir = (-23.045793381117505, -24.88170966984609))
# 13 -> 16 (orig = (190.14571822793232, 128.30965570387585), dir = (79.01988433330752, -28.051336388507366))
# 15 -> 16 (orig = (216.69566774888307, 118.88466639398698), dir = (73.02548575772225, -15.12375571400571))
# 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (19.96477985786345, 66.01406613236148))
# 12 -> 18 (orig = (234.99674981137838, 6.045745691439728), dir = (-19.96477985786345, -66.01406613236148))
# 11 -> 17 (orig = (206.20439934161288, 227.7131936941337), dir = (72.90139111252176, -110.00356711561861))
# 18 -> 13 (orig = (242.8961379639692, 32.16527897068769), dir = (62.921180964299474, 39.034284753825546))
# 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (13.92636694309644, 23.95458006933484))
# 16 -> 19 (orig = (267.9689659932995, 134.06044404595028), dir = (-13.92636694309644, -23.95458006933484))
# 16 -> 17 (orig = (220.47985653361397, 206.17243583805075), dir = (114.99836579135564, -1.947506623600816))
# 18 -> 15 (orig = (253.77673804730324, 38.91525466148624), dir = (68.91557953988473, 26.10670407932389))
# 15 -> 19 (orig = (254.58440434310683, 111.03781689182186), dir = (59.09911881462581, -39.07833578334055))
# INCOMPLETE EDGE 19 -> 17 (orig = (309.02066566628395, 204.67299007585876), dir = (128.92473273445208, 22.007073445734022))
# INCOMPLETE EDGE 18 -> 19 (orig = (323.6351547948332, 65.37912575789551), dir = (128.01469835451056, -12.971631704016659))
# INCOMPLETE EDGE 8 -> 18 (orig = (110.9470363391641, -404.1278724078285), dir = (-29.908859217596778, -174.0060539401856))
# Did it without crashing

# %%
pts
# Out:
# array([[5.80422285e+01, 9.70424354e+01],
#        [2.45994724e+02, 2.15062901e+02],
#        [8.91472245e+01, 2.20015415e+02],
#        [1.30929163e+02, 2.59899312e+02],
#        [2.33091249e+02, 2.32009340e+02],
#        [2.90028884e+02, 2.52980960e+02],
#        [1.70709103e+01, 1.01227005e+01],
#        [1.64920528e+02, 3.96799467e+00],
#        [2.48008720e+02, 1.75997180e+02],
#        [1.15334630e-02, 5.29805219e+01],
#        [6.60150582e+01, 2.67972627e+02],
#        [2.43987617e+02, 2.19658159e+01],
#        [2.83983344e+02, 1.75926724e+02],
#        [2.84097323e+02, 1.07987682e+02],
#        [1.47980174e+02, 2.82042400e+02],
#        [1.93032889e+02, 2.16995710e+02],
#        [2.04012869e+02, 2.50453043e+01],
#        [2.09052708e+02, 2.96915271e+02],
#        [1.87993088e+02, 8.20256878e+01],
#        [5.40024820e+01, 2.70968975e+02]])

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x262D985C6A0>

# %%
# %run voronoi_utils_new.py
voronoi.draw_img((300,300))
# Out:
# ########################################################
# INSERT 1 in 0 x= 145
# #DISALING#
# #END DISABLING#
# ########################################################
# (2,)
# (2,)
# INSERT 2 in 0 x= 161
# #DISALING#
# #END DISABLING#
# Checking 0 -> 1 (orig = (92.41176470588235, 95), dir = (-18, 102)) and 0 -> 2 (orig = (4.101694915254242, 229), dir = (152, -118))
# Will occur at x= 179.54143601596047
# ########################################################
# DELETE  1 0 2 x= 179.54143601596047
# Tree at DELETE [focus: 0]->[focus: 1]->[focus: 0]->[focus: 2]->[focus: 0]
# #DISABLING#
# END DISABLING
# Checking 0 -> 1 (orig = (92.41176470588235, 95), dir = (18, -102)) and 1 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (134, -16))
# I swear I didn't find anything
# Checking 1 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (134, -16)) and 0 -> 2 (orig = (4.101694915254242, 229), dir = (-152, 118))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# INSERT 3 in 2 x= 239
# #DISALING#
# #END DISABLING#
# Checking 2 -> 3 (orig = (172.07692307692307, 163), dir = (66, 78)) and 0 -> 2 (orig = (4.101694915254242, 229), dir = (-152, 118))
# I swear I didn't find anything
# Checking 1 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (134, -16)) and 2 -> 3 (orig = (172.07692307692307, 163), dir = (-66, -78))
# Will occur at x= 239.06378559128615
# ########################################################
# DELETE  1 2 3 x= 239.06378559128615
# Tree at DELETE [focus: 0]->[focus: 1]->[focus: 0]->[focus: 2]->[focus: 3]->[focus: 2]->[focus: 0]
# #DISABLING#
# END DISABLING
# Checking 0 -> 1 (orig = (92.41176470588235, 95), dir = (18, -102)) and 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94))
# I swear I didn't find anything
# Checking 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94)) and 2 -> 3 (orig = (172.07692307692307, 163), dir = (66, 78))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 4 in 2 x= 262
# #DISALING#
# #END DISABLING#
# Checking 2 -> 4 (orig = (211.4950495049505, 230), dir = (-1, 101)) and 0 -> 2 (orig = (4.101694915254242, 229), dir = (-152, 118))
# I swear I didn't find anything
# Checking 2 -> 3 (orig = (172.07692307692307, 163), dir = (66, 78)) and 2 -> 4 (orig = (211.4950495049505, 230), dir = (1, -101))
# Will occur at x= 265.89626179897806
# ########################################################
# DELETE  3 2 4 x= 265.89626179897806
# Tree at DELETE [focus: 0]->[focus: 1]->[focus: 0]->[focus: 3]->[focus: 2]->[focus: 4]->[focus: 2]
# #DISABLING#
# END DISABLING
# Checking 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94)) and 3 -> 4 (orig = (211.69483985765123, 209.8211743772242), dir = (67, -23))
# I swear I didn't find anything
# Checking 3 -> 4 (orig = (211.69483985765123, 209.8211743772242), dir = (67, -23)) and 2 -> 4 (orig = (211.4950495049505, 230), dir = (-1, 101))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 5 in 4 x= 298
# #DISALING#
# #END DISABLING#
# Checking 4 -> 5 (orig = (273.875, 251), dir = (-21, 36)) and 2 -> 4 (orig = (211.4950495049505, 230), dir = (-1, 101))
# Will occur at x= 350.279890578396
# Checking 3 -> 4 (orig = (211.69483985765123, 209.8211743772242), dir = (67, -23)) and 4 -> 5 (orig = (273.875, 251), dir = (21, -36))
# Will occur at x= 400.55650571883905
# ########################################################
# DELETE  5 4 2 x= 350.279890578396
# Tree at DELETE [focus: 0]->[focus: 1]->[focus: 0]->[focus: 3]->[focus: 2]->[focus: 4]->[focus: 5]->[focus: 4]->[focus: 2]->[focus: 0]
# #DISABLING#
# END DISABLING
# Checking 4 -> 5 (orig = (273.875, 251), dir = (21, -36)) and 5 -> 2 (orig = (210.2064748201439, 360.14604316546763), dir = (-22, 137))
# I swear I didn't find anything
# Checking 5 -> 2 (orig = (210.2064748201439, 360.14604316546763), dir = (-22, 137)) and 0 -> 2 (orig = (4.101694915254242, 229), dir = (-152, 118))
# I swear I didn't find anything
# ########################################################
# DELETE  3 4 5 x= 400.55650571883905
# Tree at DELETE [focus: 0]->[focus: 1]->[focus: 0]->[focus: 3]->[focus: 2]->[focus: 4]->[focus: 5]->[focus: 2]->[focus: 2]->[focus: 0]
# #DISABLING#
# END DISABLING
# Checking 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94)) and 3 -> 5 (orig = (319.4797822706065, 172.8203732503888), dir = (88, -59))
# I swear I didn't find anything
# Checking 3 -> 5 (orig = (319.4797822706065, 172.8203732503888), dir = (88, -59)) and 5 -> 2 (orig = (210.2064748201439, 360.14604316546763), dir = (-22, 137))
# I swear I didn't find anything
# ############### BEFORE COMPILING #########################
# 0 -> 1 (orig = (92.41176470588235, 95), dir = (-18, 102))
# INCOMPLETE EDGE 0 -> 1 (orig = (92.41176470588235, 95), dir = (18, -102))
# INCOMPLETE EDGE 0 -> 2 (orig = (4.101694915254242, 229), dir = (-152, 118))
# 0 -> 2 (orig = (4.101694915254242, 229), dir = (152, -118))
# 1 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (134, -16))
# 2 -> 3 (orig = (172.07692307692307, 163), dir = (66, 78))
# 2 -> 3 (orig = (172.07692307692307, 163), dir = (-66, -78))
# INCOMPLETE EDGE 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94))
# 2 -> 4 (orig = (211.4950495049505, 230), dir = (-1, 101))
# 2 -> 4 (orig = (211.4950495049505, 230), dir = (1, -101))
# 3 -> 4 (orig = (211.69483985765123, 209.8211743772242), dir = (67, -23))
# 4 -> 5 (orig = (273.875, 251), dir = (-21, 36))
# 4 -> 5 (orig = (273.875, 251), dir = (21, -36))
# INCOMPLETE EDGE 5 -> 2 (orig = (210.2064748201439, 360.14604316546763), dir = (-22, 137))
# INCOMPLETE EDGE 3 -> 5 (orig = (319.4797822706065, 172.8203732503888), dir = (88, -59))
# ############### AFTER COMPILING #########################
# INCOMPLETE EDGE 0 -> 1 (orig = (79.02959641255605, 170.8322869955157), dir = (18, -102))
# INCOMPLETE EDGE 0 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (-152, 118))
# 1 -> 2 (orig = (79.02959641255605, 170.8322869955157), dir = (134, -16))
# INCOMPLETE EDGE 1 -> 3 (orig = (169.55787278415016, 160.02294056308654), dir = (68, -94))
# 2 -> 3 (orig = (211.69483985765123, 209.8211743772242), dir = (-66, -78))
# 2 -> 4 (orig = (210.2064748201439, 360.14604316546763), dir = (1, -101))
# 3 -> 4 (orig = (211.69483985765123, 209.8211743772242), dir = (67, -23))
# INCOMPLETE EDGE 3 -> 5 (orig = (319.4797822706065, 172.8203732503888), dir = (88, -59))
# 4 -> 5 (orig = (210.2064748201439, 360.14604316546763), dir = (21, -36))
# INCOMPLETE EDGE 5 -> 2 (orig = (210.2064748201439, 360.14604316546763), dir = (-22, 137))
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2263B385D68>
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2263B39F128>

# %%
# %%capture
# %run voronoi.py
img = voronoiRandom((300,300), 20, 0)

# %%
def tile(original, N, M):
    new_size = N * original.size[0], M * original.size[1]
    img = Image.new(original.mode, new_size, (0,0,0))
    for i in range(N):
        for j in range(M):
            img.paste(original,(i * size[0], j * size[1]))
    return img

# %%
img
tile(img, 3 ,3)
# Out:
# <PIL.Image.Image image mode=RGB size=900x900 at 0x262DA978A90>
