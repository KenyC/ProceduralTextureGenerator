# %%
b = True
for i in range(10):
    print("~~~~~~~~~~~~~~~{}~~~~~~~~~~~~~~~~~~~~~~".format(i))
    try:
        # %run voronoi.py
    except TypeError as e:
        b = False
        print("BHDT")
        print(e)
        break
if b:
    print("Did it without crashing")
# Out:
# ~~~~~~~~~~~~~~~0~~~~~~~~~~~~~~~~~~~~~~
# ########################################################
# INSERT 1 in 0 x= 31.101901750835108
# #DISALING#
# #END DISABLING#
# ########################################################
# (2,)
# INSERT 2 in 0 x= 41.93625589840527
# #DISALING#
# #END DISABLING#
# Checking 0 -> 2 (orig = (13.979112117398145, 79.06200787200882), dir = (-26.091803976175115, 17.916244734569197)) and 0 -> 1 (orig = (-3452.2818834868385, 274.97861027918054), dir = (222.00840638334682, -7.081890586999034))
# Will occur at x= 65.48684121675096
# ########################################################
# DELETE  2 0 1 x= 65.48684121675096
# Tree at DELETE [parent: False, focus: None, edge: 0 -> 1 (orig = (-3452.2818834868385, 274.97861027918054), dir = (222.00840638334682, -7.081890586999034))]
# 	[parent: True, focus: None, edge: 0 -> 2 (orig = (13.979112117398145, 79.06200787200882), dir = (26.091803976175115, -17.916244734569197))]
# ...

# %%
pts

# %%
img

# %%
img

# %%
None +1
