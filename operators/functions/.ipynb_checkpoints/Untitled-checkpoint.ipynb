# %%
b = True
for i in range(10):
    print("~~~~~~~~~~~~~~~{}~~~~~~~~~~~~~~~~~~~~~~".format(i))
    try:
        # %run voronoi.py
    except TypeError as e:
        b = False
        print("BHDT")
        print(e)
        break
if b:
    print("Did it without crashing")
# Out:
# ########################################################
# INSERT 1 in 0 x= 19.972467708602938
# #DISALING#
# #END DISABLING#
# ########################################################
# (2,)
# INSERT 2 in 0 x= 32.87605959716507
# #DISALING#
# #END DISABLING#
# Checking 0 -> 2 (orig = (-409.25607213494675, 36.83513551926173), dir = (165.17374654750904, 32.01208179375447)) and 0 -> 1 (orig = (6.6720797433807535, 190.04367116681829), dir = (-11.965210899952496, -19.108489905192343))
# Will occur at x= 60.08615542148671
# ########################################################
# (2,)
# (2,)
# INSERT 3 in 1 x= 37.87338034779132
# #DISALING#
# #END DISABLING#
# Checking 1 -> 3 (orig = (5.365916966017242, 161.00259937320757), dir = (29.041071793610712, 17.90091263918838)) and 0 -> 1 (orig = (6.6720797433807535, 190.04367116681829), dir = (11.965210899952496, 19.108489905192343))
# I swear I didn't find anything
# ...

# %%
pts

# %%
img

# %%
img

# %%
None +1
