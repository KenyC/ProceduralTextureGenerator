# %%
import matplotlib.pyplot as plt
from math import sqrt
from PIL import Image, ImageDraw

# %%
# %run utilities/fill_voronoi.py
# Out:
# ########################################################
# INSERT 1 in 0 x= 62.993192324653556
# List at insert
# [parent: False, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# ########################################################
# (2,)
# (2,)
# INSERT 2 in 0 x= 84.94885462665431
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (613.9093960178513, 24.944497445523318))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (613.9093960178513, 24.944497445523318)) and 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (-355.8815857765647, -46.90015974752407))
# Will occur at x= 84.97082025054397
# ########################################################
# DELETE  1 0 2 x= 84.97082025054397
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (613.9093960178513, 24.944497445523318))
# [parent: True, focus: 0, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (-355.8815857765647, -46.90015974752407))
# [parent: True, focus: 2, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318)) and 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# I swear I didn't find anything
# Checking 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754)) and 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# INSERT 3 in 0 x= 129.8725598451564
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407)) and 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615))
# Will occur at x= 269.291104362109
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 4 in 0 x= 251.97594524593288
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# [parent: True, focus: 0, edge: None]
#
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615))
# [parent: True, focus: 3, edge: None]
#
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (-2.0371351466628767, 91.82386496602615))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (-2.0371351466628767, 91.82386496602615)) and 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (254.0185774033672, -213.92725036680264))
# Will occur at x= 266.5190412033908
# ########################################################
# DELETE  3 0 4 x= 266.5190412033908
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# [parent: True, focus: 0, edge: None]
#
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615))
# [parent: True, focus: 3, edge: None]
#
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (-2.0371351466628767, 91.82386496602615))
# [parent: True, focus: 0, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (254.0185774033672, -213.92725036680264))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615)) and 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# I swear I didn't find anything
# Checking 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649)) and 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# I swear I didn't find anything
# ########################################################
# DELETE  2 0 3 x= 269.291104362109
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# [parent: True, focus: 0, edge: None]
#
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754)) and 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208))
# Will occur at x= 15547.98889501564
# Checking 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208)) and 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# Will occur at x= 2055.61178464358
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 5 in 4 x= 295.9551812775587
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845)) and 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# I swear I didn't find anything
# Checking 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# Will occur at x= 639.792778796325
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 6 in 3 x= 301.063979258154
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# had to disable: 2 3 4
# #END DISABLING#
# Checking 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762)) and 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# Will occur at x= 548.0330151704502
# Checking 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208)) and 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (-154.00460797233546, -171.19141941299762))
# Will occur at x= 303.0589834167936
# ########################################################
# DELETE  2 3 6 x= 303.0589834167936
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (-154.00460797233546, -171.19141941299762))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 1 2 3
# END DISABLING
# Checking 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754)) and 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# Will occur at x= 830.1901986311809
# Checking 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997)) and 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# INSERT 7 in 2 x= 367.03455737124784
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# had to disable: 1 2 3
# had to disable: 1 2 6
# #END DISABLING#
# Checking 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (66.12191338523328, 282.0857027445935)) and 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# Will occur at x= 411.4003093557726
# Checking 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754)) and 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (-66.12191338523328, -282.0857027445935))
# Will occur at x= 382.6531184951445
# ########################################################
# DELETE  1 2 7 x= 382.6531184951445
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (-66.12191338523328, -282.0857027445935))
# [parent: True, focus: 7, edge: None]
#
# 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (66.12191338523328, 282.0857027445935))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318)) and 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# I swear I didn't find anything
# Checking 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943)) and 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (66.12191338523328, 282.0857027445935))
# I swear I didn't find anything
# ########################################################
# DELETE  7 2 6 x= 411.4003093557726
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (66.12191338523328, 282.0857027445935))
# [parent: True, focus: 2, edge: None]
#
# 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943)) and 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# I swear I didn't find anything
# Checking 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384)) and 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 8 in 6 x= 447.00229088213774
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374)) and 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# Will occur at x= 607.6926810253282
# Checking 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384)) and 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (7.955976115911653, -145.93831162398374))
# Will occur at x= 528.1330379916251
# ########################################################
# (2,)
# (2,)
# (2,)
# INSERT 9 in 7 x= 513.9861535357879
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (7.955976115911653, -145.93831162398374))
# [parent: True, focus: 8, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401)) and 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# Will occur at x= 610.4234947931287
# Checking 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943)) and 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# Will occur at x= 935.4358293966891
# ########################################################
# DELETE  7 6 8 x= 528.1330379916251
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (7.955976115911653, -145.93831162398374))
# [parent: True, focus: 8, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 9 7 6
# END DISABLING
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401)) and 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# Will occur at x= 584.9301612046493
# Checking 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899)) and 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# I swear I didn't find anything
# ########################################################
# DELETE  6 3 4 x= 548.0330151704502
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# [parent: True, focus: 8, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# [parent: True, focus: 6, edge: None]
#
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# [parent: True, focus: 3, edge: None]
#
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 8 6 3
# had to disable: 3 4 5
# END DISABLING
# Checking 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374)) and 6 -> 4 (orig = (335.1919758176788, 678.0808959177347), dir = (405.9860502290398, 49.08803401222113))
# Will occur at x= 584.718554315771
# Checking 6 -> 4 (orig = (335.1919758176788, 678.0808959177347), dir = (405.9860502290398, 49.08803401222113)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# Will occur at x= 595.8317261845771
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 10 in 8 x= 553.946309577601
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# [parent: True, focus: 8, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 4 (orig = (335.1919758176788, 678.0808959177347), dir = (405.9860502290398, 49.08803401222113))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328)) and 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# I swear I didn't find anything
# Checking 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899)) and 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# Will occur at x= 594.9554519039154
# ########################################################
# DELETE  8 6 4 x= 584.718554315771
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# [parent: True, focus: 6, edge: None]
#
# 6 -> 4 (orig = (335.1919758176788, 678.0808959177347), dir = (405.9860502290398, 49.08803401222113))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 3 4 5
# had to disable: 6 4 5
# END DISABLING
# Checking 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328)) and 8 -> 4 (orig = (362.6161184611562, 681.3967666134878), dir = (398.03007411312814, 195.02634563620487))
# Will occur at x= 1082.39336224733
# Checking 8 -> 4 (orig = (362.6161184611562, 681.3967666134878), dir = (398.03007411312814, 195.02634563620487)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# Will occur at x= 592.1047677167297
# ########################################################
# DELETE  9 7 8 x= 584.9301612046493
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 4 (orig = (362.6161184611562, 681.3967666134878), dir = (398.03007411312814, 195.02634563620487))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 7 8 10
# END DISABLING
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401)) and 9 -> 8 (orig = (436.9763201753573, 328.33602677169205), dir = (273.9459488565805, 66.98386265365019))
# I swear I didn't find anything
# Checking 9 -> 8 (orig = (436.9763201753573, 328.33602677169205), dir = (273.9459488565805, 66.98386265365019)) and 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# Will occur at x= 592.2513651388307
# ########################################################
# DELETE  8 4 5 x= 592.1047677167297
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 8 (orig = (436.9763201753573, 328.33602677169205), dir = (273.9459488565805, 66.98386265365019))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 4 (orig = (362.6161184611562, 681.3967666134878), dir = (398.03007411312814, 195.02634563620487))
# [parent: True, focus: 4, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 10 8 4
# END DISABLING
# Checking 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328)) and 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# Will occur at x= 1013.1176096609323
# Checking 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# I swear I didn't find anything
# ########################################################
# DELETE  9 8 10 x= 592.2513651388307
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 8 (orig = (436.9763201753573, 328.33602677169205), dir = (273.9459488565805, 66.98386265365019))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401)) and 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# I swear I didn't find anything
# Checking 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309)) and 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 11 in 9 x= 630.0174510413171
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921)) and 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# Will occur at x= 750.1168139208235
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401)) and 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (-37.9243037741557, -116.03129750552921))
# Will occur at x= 844.8957715665397
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 12 in 11 x= 680.9618432847046
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (-37.9243037741557, -116.03129750552921))
# [parent: True, focus: 11, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748)) and 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# I swear I didn't find anything
# Checking 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (-37.9243037741557, -116.03129750552921)) and 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (-110.06038706007493, -50.94439224338748))
# Will occur at x= 681.006594569059
# ########################################################
# DELETE  9 11 12 x= 681.006594569059
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (-37.9243037741557, -116.03129750552921))
# [parent: True, focus: 11, edge: None]
#
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (-110.06038706007493, -50.94439224338748))
# [parent: True, focus: 12, edge: None]
#
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748))
# [parent: True, focus: 11, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 7 9 11
# END DISABLING
# Checking 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401)) and 9 -> 12 (orig = (528.6244030064884, 50.326360353937844), dir = (-147.98469083423063, -166.9756897489167))
# Will occur at x= 699.7557045450925
# Checking 9 -> 12 (orig = (528.6244030064884, 50.326360353937844), dir = (-147.98469083423063, -166.9756897489167)) and 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748))
# I swear I didn't find anything
# ########################################################
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# (2,)
# INSERT 13 in 11 x= 687.9714941590588
# List at insert
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 12 (orig = (528.6244030064884, 50.326360353937844), dir = (-147.98469083423063, -166.9756897489167))
# [parent: True, focus: 12, edge: None]
#
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748))
# [parent: True, focus: 11, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISALING#
# #END DISABLING#
# Checking 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (-78.99272047168625, 57.95404311774166)) and 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# Will occur at x= 688.3132118874927
# Checking 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748)) and 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (78.99272047168625, -57.95404311774166))
# Will occur at x= 844.6811621498624
# ########################################################
# DELETE  13 11 9 x= 688.3132118874927
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# [parent: True, focus: 7, edge: None]
#
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 12 (orig = (528.6244030064884, 50.326360353937844), dir = (-147.98469083423063, -166.9756897489167))
# [parent: True, focus: 12, edge: None]
#
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748))
# [parent: True, focus: 11, edge: None]
#
# 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (78.99272047168625, -57.95404311774166))
# [parent: True, focus: 13, edge: None]
#
# 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (-78.99272047168625, 57.95404311774166))
# [parent: True, focus: 11, edge: None]
#
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# [parent: True, focus: 9, edge: None]
#
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# ...
# DELETE  18 16 14 x= 940.0575742914356
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 15 (orig = (394.23857861844556, -256.7567310724547), dir = (7.979651510860171, -656.0000458343196))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 17 (orig = (752.436432411247, 83.91790954258943), dir = (93.97689390189609, -107.07878840925218))
# [parent: True, focus: 17, edge: None]
#
# 17 -> 19 (orig = (758.504281684383, 177.05618668346563), dir = (74.05877572446762, -28.90962912963755))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686))
# [parent: True, focus: 18, edge: None]
#
# 16 -> 18 (orig = (768.2883423170177, 257.9855352217953), dir = (42.002261106545404, 114.05267306697283))
# [parent: True, focus: 16, edge: None]
#
# 16 -> 14 (orig = (613.5658337902917, 320.54421812848886), dir = (96.97811857075959, 29.946279700779087))
# [parent: True, focus: 14, edge: None]
#
# 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686)) and 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192))
# I swear I didn't find anything
# Checking 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192)) and 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232))
# I swear I didn't find anything
# ########################################################
# DELETE  10 8 5 x= 1013.1176096609323
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 15 (orig = (394.23857861844556, -256.7567310724547), dir = (7.979651510860171, -656.0000458343196))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 17 (orig = (752.436432411247, 83.91790954258943), dir = (93.97689390189609, -107.07878840925218))
# [parent: True, focus: 17, edge: None]
#
# 17 -> 19 (orig = (758.504281684383, 177.05618668346563), dir = (74.05877572446762, -28.90962912963755))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192))
# [parent: True, focus: 14, edge: None]
#
# 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232))
# [parent: True, focus: 10, edge: None]
#
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# [parent: True, focus: 8, edge: None]
#
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# had to disable: 14 10 8
# END DISABLING
# Checking 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232)) and 10 -> 5 (orig = (646.0146692497661, 784.4277203788655), dir = (465.92754215217093, 257.9911283000423))
# Will occur at x= 1148.5219762537083
# Checking 10 -> 5 (orig = (646.0146692497661, 784.4277203788655), dir = (465.92754215217093, 257.9911283000423)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# I swear I didn't find anything
# ########################################################
# DELETE  14 10 5 x= 1148.5219762537083
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 15 (orig = (394.23857861844556, -256.7567310724547), dir = (7.979651510860171, -656.0000458343196))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 17 (orig = (752.436432411247, 83.91790954258943), dir = (93.97689390189609, -107.07878840925218))
# [parent: True, focus: 17, edge: None]
#
# 17 -> 19 (orig = (758.504281684383, 177.05618668346563), dir = (74.05877572446762, -28.90962912963755))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192))
# [parent: True, focus: 14, edge: None]
#
# 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232))
# [parent: True, focus: 10, edge: None]
#
# 10 -> 5 (orig = (646.0146692497661, 784.4277203788655), dir = (465.92754215217093, 257.9911283000423))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192)) and 14 -> 5 (orig = (719.3698732459867, 825.0456064953378), dir = (498.0191378424814, 393.0946464734046))
# Will occur at x= 6007.244285319877
# Checking 14 -> 5 (orig = (719.3698732459867, 825.0456064953378), dir = (498.0191378424814, 393.0946464734046)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# I swear I didn't find anything
# ########################################################
# DELETE  18 14 5 x= 6007.244285319877
# List at delete
# [parent: True, focus: 0, edge: None]
#
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# [parent: True, focus: 1, edge: None]
#
# 1 -> 15 (orig = (394.23857861844556, -256.7567310724547), dir = (7.979651510860171, -656.0000458343196))
# [parent: True, focus: 15, edge: None]
#
# 15 -> 17 (orig = (752.436432411247, 83.91790954258943), dir = (93.97689390189609, -107.07878840925218))
# [parent: True, focus: 17, edge: None]
#
# 17 -> 19 (orig = (758.504281684383, 177.05618668346563), dir = (74.05877572446762, -28.90962912963755))
# [parent: True, focus: 19, edge: None]
#
# 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686))
# [parent: True, focus: 18, edge: None]
#
# 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192))
# [parent: True, focus: 14, edge: None]
#
# 14 -> 5 (orig = (719.3698732459867, 825.0456064953378), dir = (498.0191378424814, 393.0946464734046))
# [parent: True, focus: 5, edge: None]
#
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# [parent: True, focus: 4, edge: None]
#
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# [parent: True, focus: 0, edge: None]
#
# #DISABLING#
# END DISABLING
# Checking 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686)) and 18 -> 5 (orig = (2910.4897808337223, 2554.5323671556603), dir = (636.9995175197864, 537.0935992411565))
# I swear I didn't find anything
# Checking 18 -> 5 (orig = (2910.4897808337223, 2554.5323671556603), dir = (636.9995175197864, 537.0935992411565)) and 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# I swear I didn't find anything
# ############### BEFORE COMPILING #########################
# 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (613.9093960178513, 24.944497445523318))
# INCOMPLETE EDGE 0 -> 1 (orig = (-7503.945674578883, 6.051876778182065), dir = (-613.9093960178513, -24.944497445523318))
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (355.8815857765647, 46.90015974752407))
# 0 -> 2 (orig = (-1288.7280024760328, 264.07968701946874), dir = (-355.8815857765647, -46.90015974752407))
# 1 -> 2 (orig = (-1348.9533612149626, 256.14283650908266), dir = (258.02781024128666, -21.955662302000754))
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (-2.0371351466628767, 91.82386496602615))
# 0 -> 3 (orig = (83.93803018869987, 621.9984079426963), dir = (2.0371351466628767, -91.82386496602615))
# INCOMPLETE EDGE 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (-254.0185774033672, 213.92725036680264))
# 0 -> 4 (orig = (-5.799316966865689, 873.9798501994006), dir = (254.0185774033672, -213.92725036680264))
# 3 -> 4 (orig = (79.94987929290191, 801.7643061060014), dir = (251.98144225670433, -122.10338540077649))
# 2 -> 3 (orig = (87.85383069463728, 445.49370353949814), dir = (357.91872092322757, -44.92370521850208))
# INCOMPLETE EDGE 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (-21.00520254218111, 43.979236031625845))
# 4 -> 5 (orig = (268.94934909285064, 894.9850527415817), dir = (21.00520254218111, -43.979236031625845))
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (154.00460797233546, 171.19141941299762))
# 3 -> 6 (orig = (146.1966338644287, 467.99379997036084), dir = (-154.00460797233546, -171.19141941299762))
# 2 -> 6 (orig = (122.08976815440235, 441.1966241401463), dir = (203.9141129508921, -216.1151246314997))
# 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (66.12191338523328, 282.0857027445935))
# 2 -> 7 (orig = (218.24209765796599, 197.95777363423545), dir = (-66.12191338523328, -282.0857027445935))
# 1 -> 7 (orig = (200.9669915559316, 124.259657604398), dir = (191.90589685605337, -304.0413650465943))
# 7 -> 6 (orig = (244.77868757637196, 311.16672710124703), dir = (270.03602633612536, 65.97057811309384))
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (-7.955976115911653, 145.93831162398374))
# 6 -> 8 (orig = (373.8162709881492, 475.9497760862725), dir = (7.955976115911653, -145.93831162398374))
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (-4.046053595456527, 146.9515961645401))
# 7 -> 9 (orig = (440.4546549707583, 202.00382722969198), dir = (4.046053595456527, -146.9515961645401))
# 7 -> 8 (orig = (380.9855271945812, 344.44244987975475), dir = (277.992002452037, -79.9677335108899))
# 6 -> 4 (orig = (335.1919758176788, 678.0808959177347), dir = (405.9860502290398, 49.08803401222113))
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (46.89226549686168, 106.94401869546328))
# 8 -> 10 (orig = (490.1937600451501, 429.0575105894108), dir = (-46.89226549686168, -106.94401869546328))
# 8 -> 4 (orig = (362.6161184611562, 681.3967666134878), dir = (398.03007411312814, 195.02634563620487))
# 9 -> 8 (orig = (436.9763201753573, 328.33602677169205), dir = (273.9459488565805, 66.98386265365019))
# 8 -> 5 (orig = (369.3797663761924, 684.7108115106695), dir = (419.03527665530925, 151.04710960457902))
# 9 -> 10 (orig = (447.1171555937288, 330.81561199531984), dir = (227.05368335971883, -39.96015604181309))
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (37.9243037741557, 116.03129750552921))
# 9 -> 11 (orig = (565.8041088744721, 164.07952345553628), dir = (-37.9243037741557, -116.03129750552921))
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (110.06038706007493, 50.94439224338748))
# 11 -> 12 (orig = (536.6022852141027, 54.01913639546135), dir = (-110.06038706007493, -50.94439224338748))
# 9 -> 12 (orig = (528.6244030064884, 50.326360353937844), dir = (-147.98469083423063, -166.9756897489167))
# 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (-78.99272047168625, 57.95404311774166))
# 11 -> 13 (orig = (605.160006945731, 243.07224392722253), dir = (78.99272047168625, -57.95404311774166))
# 13 -> 9 (orig = (594.2408700694208, 251.08321159056595), dir = (-41.06841669753055, 173.98534062327087))
# 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (32.0915956903105, 135.10351817336232))
# 10 -> 14 (orig = (617.6866560235364, 396.9659148991003), dir = (-32.0915956903105, -135.10351817336232))
# 7 -> 12 (orig = (447.16159974159734, -41.590632460356034), dir = (-143.9386372387741, -313.9272859134568))
# 13 -> 10 (orig = (580.9814898089885, 307.2562510348528), dir = (185.98526666218828, 134.02518458145778))
# 13 -> 14 (orig = (599.5572676967013, 320.6423762093101), dir = (153.89367097187778, -1.0783335919045385))
# 12 -> 15 (orig = (678.9553193786716, 14.031528289042235), dir = (39.98760810641912, 38.031394874268585))
# 12 -> 15 (orig = (678.9553193786716, 14.031528289042235), dir = (-39.98760810641912, -38.031394874268585))
# 13 -> 16 (orig = (651.2771854551239, 299.9877963283407), dir = (-56.91555240111819, 31.024613292683625))
# 13 -> 16 (orig = (651.2771854551239, 299.9877963283407), dir = (56.91555240111819, -31.024613292683625))
# 16 -> 14 (orig = (613.5658337902917, 320.54421812848886), dir = (96.97811857075959, 29.946279700779087))
# 1 -> 12 (orig = (387.61740947066437, -171.45531926199726), dir = (47.96725961727929, -617.968650960051))
# INCOMPLETE EDGE 1 -> 15 (orig = (394.23857861844556, -256.7567310724547), dir = (7.979651510860171, -656.0000458343196))
# 12 -> 17 (orig = (743.473384175066, 108.00842219093833), dir = (-53.98928579547698, 145.11018328352077))
# 12 -> 17 (orig = (743.473384175066, 108.00842219093833), dir = (53.98928579547698, -145.11018328352077))
# INCOMPLETE EDGE 15 -> 17 (orig = (752.436432411247, 83.91790954258943), dir = (93.97689390189609, -107.07878840925218))
# 17 -> 11 (orig = (730.2168425526953, 143.63880989073263), dir = (56.07110126459794, 196.05457552690825))
# 16 -> 18 (orig = (768.2883423170177, 257.9855352217953), dir = (42.002261106545404, 114.05267306697283))
# 16 -> 18 (orig = (768.2883423170177, 257.9855352217953), dir = (-42.002261106545404, -114.05267306697283))
# 17 -> 13 (orig = (732.0332704431625, 149.99001382661152), dir = (135.06382173628418, 138.1005324091666))
# 13 -> 18 (orig = (761.6082449025055, 239.84644112540232), dir = (14.913291294572787, -145.07728635965645))
# 13 -> 19 (orig = (760.3346910915329, 182.06719791540596), dir = (61.005046011816574, 167.01016153880414))
# 13 -> 19 (orig = (760.3346910915329, 182.06719791540596), dir = (-61.005046011816574, -167.01016153880414))
# INCOMPLETE EDGE 17 -> 19 (orig = (758.504281684383, 177.05618668346563), dir = (74.05877572446762, -28.90962912963755))
# INCOMPLETE EDGE 19 -> 18 (orig = (765.9636131525523, 197.47718846795942), dir = (75.91833730638936, 21.932875179147686))
# 18 -> 14 (orig = (814.1356454235569, 382.47901091702755), dir = (138.980379677305, 143.99895276775192))
# 10 -> 5 (orig = (646.0146692497661, 784.4277203788655), dir = (465.92754215217093, 257.9911283000423))
# 14 -> 5 (orig = (719.3698732459867, 825.0456064953378), dir = (498.0191378424814, 393.0946464734046))
# INCOMPLETE EDGE 18 -> 5 (orig = (2910.4897808337223, 2554.5323671556603), dir = (636.9995175197864, 537.0935992411565))

# %%
width = 300
N_X = 8

# find the height that yields the square-most texture
# we must ensure that N_Y is even for proper tiling
step_x = width / N_X
step_y = step_x * sqrt(3)/2

height = int(2 * step_y * (width // (2 * step_y)))
N_Y = int(height // step_y) + 1

# %%
points.shape

# %%
# Constructing points
# We first build a rectangular grid

xs = np.arange(width, step = step_x) # shape: N_X
ys = np.arange(height, step = step_y) # shape: N_Y

xv, yv = np.meshgrid(xs, ys) # shape of each : N_X, N_Y
points = np.stack((xv, yv), axis = 2) # shape N_X, N_Y, 2

# We now shift odd rows by half a step
points[1::2, :, 0] += step_x / 2

# We flatten the first two axis to get a list of points
points = np.reshape(points, (N_X * N_Y, 2))

# %%
def small_pt(draw, pos, radius = 10):
    draw.ellipse((pos[0] - radius, pos[1] - radius, pos[0] + radius, pos[1] + radius),
                (255,255,255))

# %%
img = Image.new("RGB", (width + 1, height + 1), (0,0,0))
draw = ImageDraw.Draw(img)

for i in range(points.shape[0]):
    small_pt(draw, points[i], radius = 2)

img

# %%
# Jitter to avoid uniformity
points_jitter = points + np.random.normal(scale = 1/5. * step_x, size = points.shape)

# Create 9 copies of each points for tiling
decalX = np.array([width, 0.], dtype = "float")
decalY = np.array([0., height], dtype = "float")
points_jitter = np.concatenate([points_jitter + i * decalX + j * decalY for i in range(3) for j in range(3)])

# Jitter to avoid degenerates due to tiling
points_jitter = points_jitter + np.random.normal(scale = 1/100., size = points_jitter.shape)

voronoi = VoronoiFill(points_jitter.tolist())

# %%
voronoi.compute_cells()
img = voronoi.fill_img((2*width, 2*height), center = (-0.5 * width, -0.5 * height))

# %%
plt.imsave("test_texture.png", 1 - img[ : height, : width], cmap = "Greys")

# %%
def plane(origin, normal, coords):
    dot_product = np.dot(coords - origin, normal) > 0
    
    plane = np.full_like(dot_product, 0.)
    plane[dot_product] = 1.
    
    return plane

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x1A2EEF11B38>

# %%
plt.imshow(fill_img2(voronoi, size))

# %%
def fill_img2(voron, size):
    center = np.array([0.,0.])
    w, h = size

    img = np.full((w, h), 1.)

    # We create a coordinate array
    # Shape: w
    x = np.arange(w) + 0.5 - center[0]
    # Shape: h
    y = np.arange(h) + 0.5 - center[1]
    # Shapes: (w, h)
    xv, yv = np.meshgrid(x, y)

    # coordinate array
    # Shape: (w, h, 2)
    coords = np.stack((xv, yv), axis = 2)



    # Constructing masks for every cell

    for cell in voron.cells.values():

        cell.mask = np.full_like(img, 1.)
        cell.dists = []
        
        for edge in cell.edges:

            # Determining origin and inward-pointing normal of edge
            edge.origin = np.array(edge.origin)
            edge.normal = np.array([-edge.dir[1], edge.dir[0]])
            if np.dot(edge.normal, np.array(cell.pt) - edge.origin)  < 0:
                normal = - edge.normal
            else:
                normal = edge.normal

            # Multiplying positive value of plane
            dist = np.dot(coords - edge.origin, normal) / np.linalg.norm(normal)
            cell.dists.append(dist)

            mult = (dist >= 0).astype("float")
            cell.mask *= mult

    # Multiplying distances
    for cell in voron.cells.values():
        for edge, dist in zip(cell.edges, cell.dists):
            # Multiplying positive value of plane
            img *= cell.mask * dist + (1 - cell.mask) 

        # Cell-wise renormalization
        maximum = np.max(cell.mask * img)
        img /= cell.mask * maximum + (1 - cell.mask)
    return img

# %%
# %timeit fill_img2(voronoi, size)
# Out:
# 12.1 s ± 170 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit voronoi.fill_img(size)
# Out:
# 16.3 s ± 156 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
A = np.array([1.58, 0.67])
B = np.array([3.22, 1.65])
C = np.array([1.04, 3.13])
D = np.array([5.67, 1.79])

# %%
def real_edge(pt1, pt2, boundary = False):
    toReturn = Edge(None, None, pt1, pt2 - pt1)
    if boundary:
        toReturn.add_boundary(pt2)
    return toReturn

# %%
e1 = real_edge(A, B)
e2 = real_edge(C, D, True)

# %%
e1.intersect(e2)

# %%
e1.intersect_with_boundary(e2)

# %%
img
#tile(img, 3 ,3)

# %%
tile(img,2 ,2)

# %%
a = np.array([2, 4 ,8])
a % 3

# %% [markdown]
# # Speed test

# %%
import numpy as np

l = np.random.randint(15, size = (900, 900))
i_mask = np.random.randint(2, size = l.shape)
b_mask = (i_mask == 1)

def boolean_mask(n = 100):
    test = np.full_like(l, 0.)
    for i in range(n):
        test[b_mask] += l[b_mask]
    
def integer_mask(n = 100):
    test = np.full_like(l, 0.)
    for i in range(n):
        test += i_mask * l

# %%
b_mask.astype("float")
